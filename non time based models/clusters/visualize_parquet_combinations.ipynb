# %%
import pandas as pd

# Load the DataFrame from the Parquet file
df = pd.read_parquet('product_recommendations_single_ANN_with_PCA.parquet')

# Display the first few rows of the DataFrame
df
# Out:
#                 ProductID                      SingleProduct_Recommendations
# 0     3260004767786243986  [2041478808931745909, 2943167493552069291, 752...
# 1     4081002095016762501  [1607208898116947879, 2465407962934372163, 704...
# 2     6392464777854173474  [6445139778739139303, 4279544621748667016, 449...
# 3     1064014581685647413  [8108226241026158269, 2465407962934372163, 178...
# 4     7562536307774112492  [6445139778739139303, 6786912353547729589, 545...
# ...                   ...                                                ...
# 4512  1429940053487484364  [5229209766901083716, 3783450815054465256, 193...
# 4513   887398846522768595  [7059076208994509066, 8294014465941231530, 879...
# 4514  2749350322351612594  [2729024956189258284, 9050180797428890648, 648...
# 4515  3297675260641023579  [2729024956189258284, 1012852661035806522, 648...
# 4516  5539197125557233330  [2729024956189258284, 1012852661035806522, 905...
#
# [4517 rows x 2 columns]

# %%
import pandas as pd

# Load the DataFrame from the Parquet file
df = pd.read_parquet("multi_product_combo_recommendations_ANN_with_PCA.parquet")

# Display the first few rows of the DataFrame
df
# Out:
#                 ProductID                        Combination_Recommendations
# 0     3260004767786243986  [{'combo': '3260004767786243986', 'recommendat...
# 1     4081002095016762501  [{'combo': '4081002095016762501', 'recommendat...
# 2     6392464777854173474  [{'combo': '6392464777854173474', 'recommendat...
# 3     1064014581685647413  [{'combo': '1064014581685647413', 'recommendat...
# 4     7562536307774112492  [{'combo': '7562536307774112492', 'recommendat...
# ...                   ...                                                ...
# 4512  1429940053487484364  [{'combo': '1429940053487484364', 'recommendat...
# 4513   887398846522768595  [{'combo': '887398846522768595', 'recommendati...
# 4514  2749350322351612594  [{'combo': '2749350322351612594', 'recommendat...
# 4515  3297675260641023579  [{'combo': '3297675260641023579', 'recommendat...
# 4516  5539197125557233330  [{'combo': '5539197125557233330', 'recommendat...
#
# [4517 rows x 2 columns]
