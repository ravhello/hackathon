# %%
import pandas as pd
import numpy as np
from collections import defaultdict

# Load the final_dataframe.csv into a DataFrame
final_df = pd.read_csv('final_dataframe.csv')
display(final_df)
display(final_df.dtypes)
# Out:
#                    ClientID            ProductID            TransactionDate  \
# 0            39370740138294  1440540189819119258  2024-12-17 00:00:00+00:00
# 1            39370740138294  1830527890021285361  2024-10-27 00:00:00+00:00
# 2            39370740138294  3095307643986324846  2024-10-28 00:00:00+00:00
# 3            41168361649132  4786639895536460836  2024-03-03 00:00:00+00:00
# 4           118552773044620  7951360260357319889  2024-12-09 00:00:00+00:00
# ...                     ...                  ...                        ...
# 896958  9223352473445645109  1102195885428775766  2025-02-05 00:00:00+00:00
# 896959  9223352473445645109  5760088997185117368  2024-05-08 00:00:00+00:00
# 896960  9223352473445645109  5760088997185117368  2024-05-21 00:00:00+00:00
# 896961  9223352473445645109  5760088997185117368  2024-05-23 00:00:00+00:00
# 896962  9223363787153601649  6542734401418447353  2024-12-03 00:00:00+00:00
#
#                     StoreID StoreCountry   Category FamilyLevel1  \
# 0       7704230050291051317          GBR   Football       Jersey
# 1       4823099650757441528          GBR   Football       Shorts
# 2       4823099650757441528          GBR   Handball         Ball
# 3       7913334853958149044          FRA  Badminton       Racket
# 4       3306498059038628287          USA   Baseball        Glove
# ...                     ...          ...        ...          ...
# 896958  7072849857188684803          ARE  Badminton  Shuttlecock
# 896959  7072849857188684803          ARE     Tennis         Ball
# 896960  7072849857188684803          ARE     Tennis         Ball
# 896961  7072849857188684803          ARE     Tennis         Ball
# 896962  3306498059038628287          USA  Badminton       Racket
#
#                 FamilyLevel2 Universe ClientSegment ClientGender   Age  \
# 0           Nike Away Jersey    Women         LOYAL            F  22.0
# 1               Nike Dri-FIT    Women         LOYAL            F  22.0
# 2            Select Ultimate      Men         LOYAL            F  22.0
# 3            Yonex Astrox 99    Women         LOYAL            F   NaN
# 4               Wilson A2000      Men         LOYAL            F  52.0
# ...                      ...      ...           ...          ...   ...
# 896958  Victor Gold Champion      Men         LOYAL            F   NaN
# 896959        Wilson US Open      Men         LOYAL            F   NaN
# 896960        Wilson US Open      Men         LOYAL            F   NaN
# 896961        Wilson US Open      Men         LOYAL            F   NaN
# 896962     Victor Thruster K    Women         LOYAL            M   NaN
#
#        ClientCountry  ClientOptINEmail  ClientOptINPhone  Quantity_sold  \
# 0                GBR                 1                 1              2
# 1                GBR                 1                 1              1
# 2                GBR                 1                 1              2
# 3                FRA                 1                 1              3
# 4                USA                 1                 0              2
# ...              ...               ...               ...            ...
# 896958           ARE                 0                 0              1
# 896959           ARE                 0                 0              1
# 896960           ARE                 0                 0              1
# 896961           ARE                 0                 0              2
# 896962           USA                 0                 0              3
#
#         SalesNetAmountEuro  product_avg_price_order  avg_price    Weekday
# 0                    14.99                 7.495000   8.355914    Tuesday
# 1                    13.99                13.990000   9.181570     Sunday
# 2                    78.99                39.495000  53.747074     Monday
# 3                    21.98                 7.326667   9.759794     Sunday
# 4                    38.99                19.495000  26.422090     Monday
# ...                    ...                      ...        ...        ...
# 896958               27.99                27.990000  16.059312  Wednesday
# 896959               26.99                26.990000  15.618155  Wednesday
# 896960                5.99                 5.990000  15.618155    Tuesday
# 896961               23.99                11.995000  15.618155   Thursday
# 896962               25.98                 8.660000   8.876234    Tuesday
#
# [896963 rows x 20 columns]
# ClientID                     int64
# ProductID                    int64
# TransactionDate             object
# StoreID                      int64
# StoreCountry                object
# Category                    object
# FamilyLevel1                object
# FamilyLevel2                object
# Universe                    object
# ClientSegment               object
# ClientGender                object
# Age                        float64
# ClientCountry               object
# ClientOptINEmail             int64
# ClientOptINPhone             int64
# Quantity_sold                int64
# SalesNetAmountEuro         float64
# product_avg_price_order    float64
# avg_price                  float64
# Weekday                     object
# dtype: object

# %%
final_df['TransactionDate'] = pd.to_datetime(final_df['TransactionDate'])
final_df = final_df.sort_values(by='TransactionDate')
display(final_df)
# Out:
#                    ClientID            ProductID           TransactionDate  \
# 336216  3440641480478789397  1925906658469214457 2023-01-01 00:00:00+00:00
# 204074  2082493611967540228  5893117420814823680 2023-01-01 00:00:00+00:00
# 766614  7896774237505151188   257035051203299958 2023-01-01 00:00:00+00:00
# 766617  7896774237505151188  1527077913232062118 2023-01-01 00:00:00+00:00
# 109537  1124647793993972767  8822915206695862777 2023-01-01 00:00:00+00:00
# ...                     ...                  ...                       ...
# 857606  8814766099908862144  3812923463855630464 2025-02-15 00:00:00+00:00
# 812176  8361760437617137777  4423794612747377145 2025-02-15 00:00:00+00:00
# 398980  4088506922773714926  8166154267929175071 2025-02-15 00:00:00+00:00
# 702275  7222914074110101995  8416641728304029823 2025-02-15 00:00:00+00:00
# 193161  1974857103601720390  4276734838749825428 2025-02-15 00:00:00+00:00
#
#                     StoreID StoreCountry  Category FamilyLevel1  \
# 336216  8383785479559769762          FRA  Football         Ball
# 204074  1172561306716917447          ARE   Cycling       Helmet
# 766614  6332090558343235680          FRA  Football       Shorts
# 766617  6332090558343235680          FRA  Handball         Ball
# 109537  5906069635056395270          FRA  Football         Ball
# ...                     ...          ...       ...          ...
# 857606  9099531021898466037          USA     Beach      Goggles
# 812176  5766738857292149683          USA     Rugby       Jersey
# 398980  5792828652092282432          USA   Cycling       Helmet
# 702275  7242889412692100661          USA     Rugby         Ball
# 193161  1172561306716917447          ARE    Tennis         Ball
#
#                  FamilyLevel2 Universe ClientSegment ClientGender   Age  \
# 336216      Adidas Telstar 18      Men         LOYAL            F  44.0
# 204074           Kask Protone      Men         LOYAL            F  40.0
# 766614      Adidas Squadra 21      Men         LOYAL            F  27.0
# 766617         Molten H3X5001    Women         LOYAL            F  27.0
# 109537      Adidas Telstar 18    Women         LOYAL            M  57.0
# ...                       ...      ...           ...          ...   ...
# 857606  Speedo Vanquisher 2.0      Men         LOYAL            F   NaN
# 812176     Adidas Performance    Women         LOYAL            F   NaN
# 398980     Bell Super 3R MIPS      Men         LOYAL            F   NaN
# 702275         Adidas Torpedo      Men           TOP            M  28.0
# 193161      Penn Championship    Women         LOYAL            F  23.0
#
#        ClientCountry  ClientOptINEmail  ClientOptINPhone  Quantity_sold  \
# 336216           USA                 1                 1              4
# 204074           ARE                 1                 1              1
# 766614           GBR                 0                 0              4
# 766617           GBR                 0                 0              3
# 109537           FRA                 1                 0              1
# ...              ...               ...               ...            ...
# 857606           USA                 1                 1              6
# 812176           USA                 0                 0              1
# 398980           USA                 1                 1              1
# 702275           USA                 1                 1              3
# 193161           USA                 1                 1              1
#
#         SalesNetAmountEuro  product_avg_price_order  avg_price   Weekday
# 336216               26.97                 6.742500   6.912560    Sunday
# 204074               41.99                41.990000  16.685385    Sunday
# 766614               24.00                 6.000000   3.798335    Sunday
# 766617              169.98                56.660000  56.603400    Sunday
# 109537               18.99                18.990000  13.253737    Sunday
# ...                    ...                      ...        ...       ...
# 857606               41.98                 6.996667   5.493780  Saturday
# 812176                5.99                 5.990000  16.994536  Saturday
# 398980               54.99                54.990000  30.599207  Saturday
# 702275               37.98                12.660000  13.500647  Saturday
# 193161               25.99                25.990000  17.078333  Saturday
#
# [896963 rows x 20 columns]

# %%
# =============================================================================
# 1. Create a "Brand" column in final_df based on FamilyLevel2 using the mapping
# -----------------------------------------------------------------------------
brand_mapping = {
    "Nike Ordem V": "Nike",
    "Nike Dri-FIT": "Nike",
    "Adidas Telstar 18": "Adidas",
    "Adidas Home Jersey": "Adidas",
    "Adidas Squadra 21": "Adidas",
    "Adidas Predator": "Adidas",
    "Nike Away Jersey": "Nike",
    "Puma Future": "Puma",
    "Trek Domane SL7": "Trek",
    "Bell Super 3R MIPS": "Bell",
    "Giro Synthe MIPS": "Giro",
    "Kask Protone": "Kask",
    "Specialized S-Works Roubaix": "Specialized",
    "Giant TCR Advanced Pro": "Giant",
    "Victor Thruster K": "Victor",
    "Yonex AS-30": "Yonex",
    "Victor Gold Champion": "Victor",
    "Yonex Astrox 99": "Yonex",
    "Mizuno Wave Mirage": "Mizuno",
    "Select Ultimate": "Select",
    "Molten H3X5001": "Molten",
    "Asics Gel-Blast": "Asics",
    "Nike Mercurial Vapor": "Nike",
    "Puma Third Jersey": "Puma",
    "Penn Championship": "Penn",
    "Babolat Pure Drive": "Babolat",
    "Head Graphene 360+ Speed Pro": "Head",
    "Wilson US Open": "Wilson",
    "Wilson Pro Staff RF97": "Wilson",
    "Nike AeroBill Classic99": "Nike",
    "Titleist T100 Irons": "Titleist",
    "FootJoy Pro/SL": "FootJoy",
    "FootJoy WeatherSof": "FootJoy",
    "Callaway Chrome Soft": "Callaway",
    "Adidas CodeChaos": "Adidas",
    "Titleist Pro V1": "Titleist",
    "Callaway JAWS MD5 Wedges": "Callaway",
    "Warrior Alpha DX": "Warrior",
    "Warrior Covert PX+": "Warrior",
    "Bauer Nexus 2N Pro": "Bauer",
    "Mikasa V200W": "Mikasa",
    "Tachikara SV5WSC": "Tachikara",
    "Molten FLISTATEC": "Molten",
    "Rawlings Quatro Pro": "Rawlings",
    "Easton ADV 360": "Easton",
    "Nike Air Zoom BB NXT": "Nike",
    "Adidas Harden Vol. 4": "Adidas",
    "Wilson Evolution Basketball": "Wilson",
    "Spalding NBA Official Game Ball": "Spalding",
    "Under Armour Curry 7": "Under Armour",
    "CCM Fitlite": "CCM",
    "A&R Sports Ice Hockey Puck": "A&R Sports",
    "Green Biscuit Training Puck": "Green Biscuit",
    "Adidas Torpedo": "Adidas",
    "Canterbury Advantage": "Canterbury",
    "Rhino Vortex Elite": "Rhino",
    "Canterbury Vapodri": "Canterbury",
    "Adidas Rugby Shorts": "Adidas",
    "Adidas Performance": "Adidas",
    "Gilbert Omega": "Gilbert",
    "SS Test": "SS",
    "Bauer RE-AKT": "Bauer",
    "CCM Ribcor Trigger": "CCM",
    "Adidas Climalite": "Adidas",
    "New Balance Furon": "New Balance",
    "Arena Carbon Air2": "Arena",
    "Arena Cobra Ultra": "Arena",
    "Speedo Fastskin LZR Racer X": "Speedo",
    "DeMarini CF": "DeMarini",
    "Easton Ghost": "Easton",
    "Dudley Thunder Heat": "Dudley",
    "Worth Dream Seam": "Worth",
    "Puma Final 1": "Puma",
    "TaylorMade SIM2 Driver": "TaylorMade",
    "Nike Air Zoom Infinity Tour": "Nike",
    "Nike Streak": "Nike",
    "Wilson A2000": "Wilson",
    "Kookaburra Kahuna": "Kookaburra",
    "Titleist Tour Performance": "Titleist",
    "Callaway Dawn Patrol": "Callaway",
    "Rawlings Heart of the Hide": "Rawlings",
    "Puma EvoSpeed": "Puma",
    "TYR Blackhawk Racing": "TYR",
    "Mizuno LR6": "Mizuno",
    "Rawlings Official MLB": "Rawlings",
    "Speedo Vanquisher 2.0": "Speedo",
    "Wilson A1030": "Wilson",
    "Louisville Slugger Meta": "Louisville Slugger",
    "Under Armour Tech": "Under Armour",
    "Bridgestone Tour B XS": "Bridgestone",
    "Gray-Nicolls GN5": "Gray-Nicolls",
    "Masuri Vision Series": "Masuri",
    "Nike Flex Stride": "Nike",
    "TaylorMade Stratus Tech": "TaylorMade",
    "Shrey MasterClass": "Shrey",
    "Kookaburra Ghost": "Kookaburra",
    "SG Test": "SG",
    "Adidas Own The Run": "Adidas",
    "Adidas Howzat": "Adidas",
    "Smith I/O Mag": "Smith",
    "Kookaburra Turf": "Kookaburra",
    "SG Litevate": "SG",
    "Salomon QST 99": "Salomon",
    "Nike Air Zoom Pegasus": "Nike",
    "Gray-Nicolls Test Opener": "Gray-Nicolls",
    "Brooks Ghost": "Brooks",
    "Gray-Nicolls Legend": "Gray-Nicolls",
    "Rossignol Experience 88": "Rossignol",
    "Dukes County International": "Dukes",
    "Anon M4": "Anon",
    "Asics Gel-Kayano": "Asics",
    "New Balance CK10": "New Balance",
    "BalanceFrom Puzzle Mat": "BalanceFrom",
    "Leki Micro Vario": "Leki",
    "SS Ton Gladiator": "SS",
    "Black Diamond Trail": "Black Diamond",
    "New Balance Fresh Foam": "New Balance",
    "Jackson Ultima SoftSkate": "Jackson Ultima",
    "Jerry's Skating World Dress": "Jerry's Skating World",
    "Atomic Vantage 97 Ti": "Atomic",
    "Oakley Flight Deck": "Oakley",
    "ChloeNoel Figure Skating Dress": "ChloeNoel",
    "Riedell 133 Diamond": "Riedell",
    "We Sell Mats Gymnastics Folding Mat": "We Sell Mats"
}

def extract_brand(product_name, brand_mapping):
    return brand_mapping.get(product_name, "Unknown Brand")

# Apply the function to create a new column "Brand" in final_df
final_df["Brand"] = final_df["FamilyLevel2"].apply(lambda x: extract_brand(x, brand_mapping))

display(final_df)
# Out:
#                    ClientID            ProductID           TransactionDate  \
# 336216  3440641480478789397  1925906658469214457 2023-01-01 00:00:00+00:00
# 204074  2082493611967540228  5893117420814823680 2023-01-01 00:00:00+00:00
# 766614  7896774237505151188   257035051203299958 2023-01-01 00:00:00+00:00
# 766617  7896774237505151188  1527077913232062118 2023-01-01 00:00:00+00:00
# 109537  1124647793993972767  8822915206695862777 2023-01-01 00:00:00+00:00
# ...                     ...                  ...                       ...
# 857606  8814766099908862144  3812923463855630464 2025-02-15 00:00:00+00:00
# 812176  8361760437617137777  4423794612747377145 2025-02-15 00:00:00+00:00
# 398980  4088506922773714926  8166154267929175071 2025-02-15 00:00:00+00:00
# 702275  7222914074110101995  8416641728304029823 2025-02-15 00:00:00+00:00
# 193161  1974857103601720390  4276734838749825428 2025-02-15 00:00:00+00:00
#
#                     StoreID StoreCountry  Category FamilyLevel1  \
# 336216  8383785479559769762          FRA  Football         Ball
# 204074  1172561306716917447          ARE   Cycling       Helmet
# 766614  6332090558343235680          FRA  Football       Shorts
# 766617  6332090558343235680          FRA  Handball         Ball
# 109537  5906069635056395270          FRA  Football         Ball
# ...                     ...          ...       ...          ...
# 857606  9099531021898466037          USA     Beach      Goggles
# 812176  5766738857292149683          USA     Rugby       Jersey
# 398980  5792828652092282432          USA   Cycling       Helmet
# 702275  7242889412692100661          USA     Rugby         Ball
# 193161  1172561306716917447          ARE    Tennis         Ball
#
#                  FamilyLevel2 Universe ClientSegment  ...   Age  \
# 336216      Adidas Telstar 18      Men         LOYAL  ...  44.0
# 204074           Kask Protone      Men         LOYAL  ...  40.0
# 766614      Adidas Squadra 21      Men         LOYAL  ...  27.0
# 766617         Molten H3X5001    Women         LOYAL  ...  27.0
# 109537      Adidas Telstar 18    Women         LOYAL  ...  57.0
# ...                       ...      ...           ...  ...   ...
# 857606  Speedo Vanquisher 2.0      Men         LOYAL  ...   NaN
# 812176     Adidas Performance    Women         LOYAL  ...   NaN
# 398980     Bell Super 3R MIPS      Men         LOYAL  ...   NaN
# 702275         Adidas Torpedo      Men           TOP  ...  28.0
# 193161      Penn Championship    Women         LOYAL  ...  23.0
#
#         ClientCountry ClientOptINEmail  ClientOptINPhone  Quantity_sold  \
# 336216            USA                1                 1              4
# 204074            ARE                1                 1              1
# 766614            GBR                0                 0              4
# 766617            GBR                0                 0              3
# 109537            FRA                1                 0              1
# ...               ...              ...               ...            ...
# 857606            USA                1                 1              6
# 812176            USA                0                 0              1
# 398980            USA                1                 1              1
# 702275            USA                1                 1              3
# 193161            USA                1                 1              1
#
#         SalesNetAmountEuro  product_avg_price_order  avg_price   Weekday  \
# 336216               26.97                 6.742500   6.912560    Sunday
# 204074               41.99                41.990000  16.685385    Sunday
# 766614               24.00                 6.000000   3.798335    Sunday
# 766617              169.98                56.660000  56.603400    Sunday
# 109537               18.99                18.990000  13.253737    Sunday
# ...                    ...                      ...        ...       ...
# 857606               41.98                 6.996667   5.493780  Saturday
# 812176                5.99                 5.990000  16.994536  Saturday
# 398980               54.99                54.990000  30.599207  Saturday
# 702275               37.98                12.660000  13.500647  Saturday
# 193161               25.99                25.990000  17.078333  Saturday
#
#          Brand
# 336216  Adidas
# 204074    Kask
# 766614  Adidas
# 766617  Molten
# 109537  Adidas
# ...        ...
# 857606  Speedo
# 812176  Adidas
# 398980    Bell
# 702275  Adidas
# 193161    Penn
#
# [896963 rows x 21 columns]

# %%
def compute_past_features(df):
    df = df.sort_values("TransactionDate").reset_index(drop=True)
    
    cumulative_spent = 0.0
    cumulative_quantity = 0
    men_items = 0
    
    brand_counts = defaultdict(int)
    unique_products = set()
    
    prev_date = None
    accum_days = 0
    transaction_count = 0
    
    # Prepare columns
    CumulativeSpent_col = []
    CumulativeQuantity_col = []
    PercentageMaleProducts_col = []
    DaysSinceLastTransaction_col = []
    MostBoughtBrandSoFar_col = []
    UniqueProductsSoFar_col = []
    AverageAmountPerTransactionSoFar_col = []
    AverageFrequencySoFar_col = []
    
    for _, row in df.iterrows():
        spent = row["SalesNetAmountEuro"]
        qty = row["Quantity_sold"]
        current_brand = row["Brand"]
        current_product = row["ProductID"]
        current_date = row["TransactionDate"]
        
        if prev_date is not None:
            days_diff = (current_date - prev_date).days
        else:
            days_diff = 0
        
        cumulative_spent += spent
        cumulative_quantity += qty
        if row["Universe"] == "Men":
            men_items += qty
        brand_counts[current_brand] += qty
        unique_products.add(current_product)
        
        transaction_count += 1
        accum_days += days_diff
        
        CumulativeSpent_col.append(cumulative_spent)
        CumulativeQuantity_col.append(cumulative_quantity)
        total_items_so_far = cumulative_quantity
        perc_male = men_items / total_items_so_far if total_items_so_far > 0 else 0
        PercentageMaleProducts_col.append(perc_male)
        
        best_brand = max(brand_counts, key=brand_counts.get)
        MostBoughtBrandSoFar_col.append(best_brand)
        
        UniqueProductsSoFar_col.append(len(unique_products))
        
        avg_amount = cumulative_spent / transaction_count if transaction_count > 0 else 0
        AverageAmountPerTransactionSoFar_col.append(avg_amount)
        
        avg_freq = accum_days / (transaction_count - 1) if transaction_count > 1 else 900
        AverageFrequencySoFar_col.append(avg_freq)
        
        DaysSinceLastTransaction_col.append(days_diff)
        prev_date = current_date
    
    df["DaysSinceLastTransaction"] = DaysSinceLastTransaction_col
    df["CumulativeSpent"] = CumulativeSpent_col
    df["CumulativeQuantity"] = CumulativeQuantity_col
    df["PercentageMaleProductsSoFar"] = PercentageMaleProducts_col
    df["MostBoughtBrandSoFar"] = MostBoughtBrandSoFar_col
    df["UniqueProductsSoFar"] = UniqueProductsSoFar_col
    df["AverageAmountPerTransactionSoFar"] = AverageAmountPerTransactionSoFar_col
    df["AverageFrequencySoFar"] = AverageFrequencySoFar_col
    
    return df

final_df = (final_df
    .groupby("ClientID", group_keys=False)
    .apply(compute_past_features)
    .sort_values("TransactionDate")
    .reset_index(drop=True)
)
# Out:
# C:\Users\rikyr\AppData\Local\Temp\ipykernel_22532\1453744084.py:78: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   final_df = (final_df

# %%
################################
# 4) PRODUCT-LEVEL AGGREGATES
################################
product_totals = (
    final_df.groupby("ProductID")
    .agg(
        TotalQuantitySold=("Quantity_sold", "sum"),
        TotalSales=("SalesNetAmountEuro", "sum")
    )
    .reset_index()
)
product_totals["AveragePrice"] = product_totals["TotalSales"] / product_totals["TotalQuantitySold"]
final_df = final_df.merge(product_totals[["ProductID","AveragePrice"]], on="ProductID", how="left")

# %%
################################
# 5) ADD BASIC TIME FEATURES
################################
final_df["DayOfWeek"] = final_df["TransactionDate"].dt.dayofweek
final_df["Month"] = final_df["TransactionDate"].dt.month

def get_season(month):
    if month in [12, 1, 2]:
        return "Winter"
    elif month in [3, 4, 5]:
        return "Spring"
    elif month in [6, 7, 8]:
        return "Summer"
    else:
        return "Fall"

final_df["Season"] = final_df["Month"].apply(get_season)

# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
from joblib import Parallel, delayed

def compute_rfm_windows_per_client_vectorized(df, windows=[30, 60, 90]):
    """
    Compute RFM windows for a single client's transactions in df using a vectorized approach for recency.
    """
    df = df.sort_values("TransactionDate").reset_index(drop=True)
    # Aggregate per day (floor TransactionDate)
    daily_data = df.groupby(df["TransactionDate"].dt.floor("D")).agg(
        TxCount=("TransactionDate", "count"),
        Spent=("SalesNetAmountEuro", "sum")
    ).sort_index()
    
    results = {}
    dates = daily_data.index.values  # numpy array of dates (dtype=datetime64[D])
    
    for w in windows:
        # Rolling sums for Frequency and Monetary
        roll_sum = daily_data.rolling(f"{w}D").sum().fillna(0)
        freq_col = f"Frequency_{w}"
        monet_col = f"Monetary_{w}"
        recency_col = f"Recency_{w}"
        
        roll_sum[freq_col] = roll_sum["TxCount"]
        roll_sum[monet_col] = roll_sum["Spent"]
        
        # Vectorized recency calculation:
        nonzero_dates = daily_data.index[daily_data["TxCount"] > 0].values
        idxs = np.searchsorted(nonzero_dates, dates, side='right') - 1
        recency = np.full(len(dates), w)
        valid = idxs >= 0
        candidates = nonzero_dates[idxs[valid]]
        window_start = dates[valid] - np.timedelta64(w-1, 'D')
        valid_candidate = candidates >= window_start
        recency_valid = (dates[valid] - candidates).astype('timedelta64[D]').astype(int)
        recency[valid] = np.where(valid_candidate, recency_valid, w)
        
        roll_sum[recency_col] = recency
        results[w] = roll_sum[[freq_col, monet_col, recency_col]]
    
    combined = daily_data.copy()
    for w in windows:
        combined = combined.join(results[w][[f"Frequency_{w}", f"Monetary_{w}", f"Recency_{w}"]])
    
    combined = combined.rename_axis("DatePivot").reset_index()
    df["DatePivot"] = df["TransactionDate"].dt.floor("D")
    df_merged = df.merge(combined, on="DatePivot", how="left")
    df_merged.drop(columns=["DatePivot", "TxCount", "Spent"], errors="ignore", inplace=True)
    df_merged = df_merged.sort_values("TransactionDate").reset_index(drop=True)
    return df_merged

def compute_rfm_windows(final_df, windows=[30, 60, 90], n_jobs=-1):
    """
    Process RFM windows for all clients in parallel.
    """
    # Group data by ClientID
    grouped = list(final_df.groupby("ClientID"))
    
    # Use joblib.Parallel to process clients in parallel.
    results = Parallel(n_jobs=n_jobs, backend="loky", verbose=1)(
        delayed(compute_rfm_windows_per_client_vectorized)(group, windows=windows)
        for _, group in grouped
    )
    
    combined_df = pd.concat(results).sort_values("TransactionDate").reset_index(drop=True)
    return combined_df

# Example usage:
final_df = compute_rfm_windows(final_df, windows=[30, 60, 90], n_jobs=-1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 32 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 1328 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 4128 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 7728 tasks      | elapsed:   14.8s
# [Parallel(n_jobs=-1)]: Done 12128 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=-1)]: Done 16356 tasks      | elapsed:   25.8s
# [Parallel(n_jobs=-1)]: Done 22016 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 28816 tasks      | elapsed:   37.9s
# [Parallel(n_jobs=-1)]: Done 36416 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done 44816 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 54016 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 62704 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 73504 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 85104 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 97504 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 109392 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 123392 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 138192 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 153792 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 165288 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 173888 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 190384 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 209184 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 228784 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done 247872 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 269072 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 291072 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 298164 out of 298164 | elapsed:  5.6min finished

# %%
from tqdm.notebook import tqdm
import pandas as pd
import numpy as np

def compute_rolling_category_pct_90d_per_client(df):
    """
    Calculate the rolling percentage of sales per category for a single client
    over a 90-day window.
    
    Steps:
      1. Ensure TransactionDate is tz-naive.
      2. Compute the floor date as 'Date'.
      3. Build a daily pivot (Date x Category) that covers EVERY day between the min
         and max date for that client.
      4. Apply a 90-day rolling window and compute percentages.
      5. Before merging, drop any pre-existing columns whose names start with "Rolling90Pct_"
         (this avoids duplicate columns after merge).
      6. Merge the rolling percentages back onto the original DataFrame.
         (Debug prints are added to help trace any missing values.)
    """
    df = df.copy()
    # Ensure TransactionDate is tz-naive
    df["TransactionDate"] = df["TransactionDate"].dt.tz_localize(None)
    df = df.sort_values("TransactionDate").reset_index(drop=True)
    
    # Compute the floor date for each transaction
    df["Date"] = df["TransactionDate"].dt.floor("D")
    
    # --- DEBUG: Print client and date range ---
    client_id = df["ClientID"].iloc[0] if "ClientID" in df.columns else "Unknown"
    #print(f"\n[DEBUG] Processing ClientID: {client_id}")
    min_date = df["Date"].min()
    max_date = df["Date"].max()
    #print(f"[DEBUG] Client Date range: {min_date} to {max_date}")
    
    # Build the daily pivot: index = Date, columns = Category, values = SalesNetAmountEuro
    daily_cat = df.groupby(["Date", "Category"])["SalesNetAmountEuro"].sum().unstack(fill_value=0)
    daily_cat.index = pd.to_datetime(daily_cat.index)
    
    # Explicitly reindex to include every day between min_date and max_date
    all_days = pd.date_range(start=min_date, end=max_date, freq="D")
    daily_cat = daily_cat.reindex(all_days, fill_value=0)
    daily_cat.index.name = "Date"
    daily_cat = daily_cat.sort_index()
    
    # --- DEBUG: Print some info about the pivot ---
    #print(f"[DEBUG] Pivot shape (days x categories): {daily_cat.shape}")
    #print(f"[DEBUG] Pivot index from {daily_cat.index.min()} to {daily_cat.index.max()}")
    
    # Apply the 90-day rolling window
    rolling_cat_90 = daily_cat.rolling("90D").sum().fillna(0)
    
    # Compute the fraction per category (if total is 0, fractions will be NaN, so later we fill with 0)
    total_spent_90 = rolling_cat_90.sum(axis=1)
    cat_pct_90 = rolling_cat_90.div(total_spent_90, axis=0).fillna(0)
    
    # Prepare for merging: reset the index and rename the index column to "DatePivot"
    cat_pct_90 = cat_pct_90.reset_index().rename(columns={"Date": "DatePivot"})
    # Rename the columns: add prefix "Rolling90Pct_" (skip "DatePivot")
    cat_pct_90 = cat_pct_90.rename(columns=lambda c: f"Rolling90Pct_{c}" if c != "DatePivot" else c)
    
    # --- DEBUG: Show a snippet of the rolling percentages pivot ---
    #print(f"[DEBUG] Rolling pivot sample:")
    #print(cat_pct_90.head())
    
    # **** NEW FIX: Drop any pre-existing Rolling90Pct columns from df before merging ****
    preexisting = [col for col in df.columns if col.startswith("Rolling90Pct_")]
    if preexisting:
        #print(f"[DEBUG] Dropping pre-existing columns: {preexisting}")
        df = df.drop(columns=preexisting, errors="ignore")
    
    # Merge the rolling percentages back into the original DataFrame
    df["DatePivot"] = df["Date"]
    df_merged = pd.merge(df, cat_pct_90, on="DatePivot", how="left")
    
    # Drop the temporary date columns
    df_merged.drop(columns=["Date", "DatePivot"], inplace=True)
    
    # --- DEBUG: Check for missing values in rolling columns ---
    roll_cols = [col for col in df_merged.columns if col.startswith("Rolling90Pct_")]
    if df_merged[roll_cols].isnull().values.any():
        #print(f"[DEBUG] Warning: Missing rolling values found for ClientID {client_id}.")
        missing = df_merged[df_merged[roll_cols].isnull().any(axis=1)][["TransactionDate"] + roll_cols]
        #print(missing)
    #else:
        #print(f"[DEBUG] No missing rolling values for ClientID {client_id}.")
    
    # For safety, fill any remaining missing values with 0
    df_merged[roll_cols] = df_merged[roll_cols].fillna(0)
    
    # Sort by TransactionDate and return
    df_merged = df_merged.sort_values("TransactionDate").reset_index(drop=True)
    return df_merged


def compute_rolling_category_percentage_90d(final_df):
    """
    Apply the compute_rolling_category_pct_90d_per_client function for each client,
    showing a global progress bar.
    """
    # Group by ClientID
    groups = [group for _, group in final_df.groupby("ClientID", group_keys=False)]
    results = []
    for group in tqdm(groups, desc="Processing clients for 90D Rolling Category"):
        result = compute_rolling_category_pct_90d_per_client(group)
        results.append(result)
    final_df_out = pd.concat(results).sort_values("TransactionDate").reset_index(drop=True)
    return final_df_out

# Apply the function to the final DataFrame
final_df = compute_rolling_category_percentage_90d(final_df)
# Out:
# Processing clients for 90D Rolling Category:   0%|          | 0/298164 [00:00<?, ?it/s]

# %%
import os
final_df.to_parquet('final_df.parquet', index=False)
# Delete the original CSV file
os.remove('final_dataframe.csv')
pd.set_option('display.max_columns', 500)
display(final_df)
# Out:
#                    ClientID            ProductID TransactionDate  \
# 0       4388436561084682799  3260004767786243986      2023-01-01
# 1       5475934562856106533  4081002095016762501      2023-01-01
# 2       7571493122530801912  6392464777854173474      2023-01-01
# 3       9054036776577299596  4007202900314609762      2023-01-01
# 4       7828763863563966653  1064014581685647413      2023-01-01
# ...                     ...                  ...             ...
# 896958  8280531702429788495  1807418090523306919      2025-02-15
# 896959  8814766099908862144  3812923463855630464      2025-02-15
# 896960  7222914074110101995  8416641728304029823      2025-02-15
# 896961  3501418887043844736  1923991482221095632      2025-02-15
# 896962    20050540156575761  6088547929558282457      2025-02-15
#
#                     StoreID StoreCountry    Category FamilyLevel1  \
# 0       1913433680162801979          USA  Basketball         Ball
# 1       7704230050291051317          GBR    Baseball         Ball
# 2       6490882301505443815          USA    Football         Ball
# 3       8616445013777361432          USA     Cycling         Bike
# 4       7215875119995113089          AUS      Tennis       Racket
# ...                     ...          ...         ...          ...
# 896958  7242889412692100661          USA    Football       Shorts
# 896959  9099531021898466037          USA       Beach      Goggles
# 896960  7242889412692100661          USA       Rugby         Ball
# 896961  6056406535832467469          USA     Cycling         Bike
# 896962  6300325018935366047          USA      Tennis         Ball
#
#                        FamilyLevel2 Universe ClientSegment ClientGender   Age  \
# 0       Wilson Evolution Basketball    Women         LOYAL            M  50.0
# 1                      Wilson A1030      Men         LOYAL            M  25.0
# 2                      Puma Final 1    Women         LOYAL            F   NaN
# 3       Specialized S-Works Roubaix      Men         LOYAL            F  25.0
# 4             Wilson Pro Staff RF97      Men         LOYAL            F   NaN
# ...                             ...      ...           ...          ...   ...
# 896958                 Nike Dri-FIT    Women         LOYAL            M   NaN
# 896959        Speedo Vanquisher 2.0      Men         LOYAL            F   NaN
# 896960               Adidas Torpedo      Men           TOP            M  28.0
# 896961  Specialized S-Works Roubaix    Women         LOYAL            M   NaN
# 896962            Penn Championship    Women   INACTIVE_1Y            M   NaN
#
#        ClientCountry  ClientOptINEmail  ClientOptINPhone  Quantity_sold  \
# 0                USA                 1                 1              2
# 1                ARE                 0                 0              1
# 2                USA                 1                 1              1
# 3                USA                 0                 0              2
# 4                AUS                 0                 0              5
# ...              ...               ...               ...            ...
# 896958           USA                 1                 1              1
# 896959           USA                 1                 1              6
# 896960           USA                 1                 1              3
# 896961           USA                 1                 1              2
# 896962           USA                 1                 0              2
#
#         SalesNetAmountEuro  product_avg_price_order  avg_price   Weekday  \
# 0                    23.99                11.995000  16.753593    Sunday
# 1                    15.99                15.990000   9.004447    Sunday
# 2                     5.99                 5.990000   4.018489    Sunday
# 3                   103.99                51.995000  65.680625    Sunday
# 4                    67.96                13.592000  12.524243    Sunday
# ...                    ...                      ...        ...       ...
# 896958                5.99                 5.990000  13.183265  Saturday
# 896959               41.98                 6.996667   5.493780  Saturday
# 896960               37.98                12.660000  13.500647  Saturday
# 896961               41.99                20.995000  24.636184  Saturday
# 896962               23.99                11.995000  15.327209  Saturday
#
#               Brand  DaysSinceLastTransaction  CumulativeSpent  \
# 0            Wilson                         0            23.99
# 1            Wilson                         0            15.99
# 2              Puma                         0             5.99
# 3       Specialized                         0           103.99
# 4            Wilson                         0            67.96
# ...             ...                       ...              ...
# 896958         Nike                         4           251.89
# 896959       Speedo                         1           190.86
# 896960       Adidas                        15          1025.72
# 896961  Specialized                         4           378.84
# 896962         Penn                         0            23.99
#
#         CumulativeQuantity  PercentageMaleProductsSoFar MostBoughtBrandSoFar  \
# 0                        2                     0.000000               Wilson
# 1                        1                     1.000000               Wilson
# 2                        1                     0.000000                 Puma
# 3                        2                     1.000000          Specialized
# 4                        5                     1.000000               Wilson
# ...                    ...                          ...                  ...
# 896958                  15                     0.733333                 Nike
# 896959                  27                     0.333333               Speedo
# 896960                  41                     0.243902               Adidas
# 896961                  24                     0.375000               Wilson
# 896962                   2                     0.000000                 Penn
#
#         UniqueProductsSoFar  AverageAmountPerTransactionSoFar  \
# 0                         1                         23.990000
# 1                         1                         15.990000
# 2                         1                          5.990000
# 3                         1                        103.990000
# 4                         1                         67.960000
# ...                     ...                               ...
# 896958                    6                         27.987778
# 896959                    5                         27.265714
# 896960                   21                         48.843810
# 896961                    8                         34.440000
# 896962                    1                         23.990000
#
#         AverageFrequencySoFar  AveragePrice  DayOfWeek  Month  Season  \
# 0                      900.00     16.753593          6      1  Winter
# 1                      900.00      9.004447          6      1  Winter
# 2                      900.00      4.018489          6      1  Winter
# 3                      900.00     65.680625          6      1  Winter
# 4                      900.00     12.524243          6      1  Winter
# ...                       ...           ...        ...    ...     ...
# 896958                  70.00     13.183265          5      2  Winter
# 896959                   4.00      5.493780          5      2  Winter
# 896960                  34.95     13.500647          5      2  Winter
# 896961                  30.60     24.636184          5      2  Winter
# 896962                 900.00     15.327209          5      2  Winter
#
#         Frequency_30  Monetary_30  Recency_30  Frequency_60  Monetary_60  \
# 0                1.0        23.99           0           1.0        23.99
# 1                1.0        15.99           0           1.0        15.99
# 2                1.0         5.99           0           1.0         5.99
# 3                1.0       103.99           0           1.0       103.99
# 4                1.0        67.96           0           1.0        67.96
# ...              ...          ...         ...           ...          ...
# 896958           3.0        73.96           0           3.0        73.96
# 896959           7.0       190.86           0           7.0       190.86
# 896960           2.0        99.97           0           2.0        99.97
# 896961           7.0       206.91           0           7.0       206.91
# 896962           1.0        23.99           0           1.0        23.99
#
#         Recency_60  Frequency_90  Monetary_90  Recency_90  \
# 0                0           1.0        23.99           0
# 1                0           1.0        15.99           0
# 2                0           1.0         5.99           0
# 3                0           1.0       103.99           0
# 4                0           1.0        67.96           0
# ...            ...           ...          ...         ...
# 896958           0           3.0        73.96           0
# 896959           0           7.0       190.86           0
# 896960           0           2.0        99.97           0
# 896961           0           7.0       206.91           0
# 896962           0           1.0        23.99           0
#
#         Rolling90Pct_Football  Rolling90Pct_Handball  Rolling90Pct_Badminton  \
# 0                         NaN                    NaN                     NaN
# 1                         0.0                    0.0                     0.0
# 2                         1.0                    0.0                     NaN
# 3                         NaN                    NaN                     NaN
# 4                         0.0                    0.0                     0.0
# ...                       ...                    ...                     ...
# 896958                    1.0                    0.0                     NaN
# 896959                    NaN                    NaN                     NaN
# 896960                    0.0                    0.0                     NaN
# 896961                    NaN                    NaN                     NaN
# 896962                    NaN                    NaN                     NaN
#
#         Rolling90Pct_Baseball  Rolling90Pct_Tennis  Rolling90Pct_Hockey  \
# 0                         NaN                  NaN                  NaN
# 1                         1.0                  NaN             0.000000
# 2                         NaN             0.000000                  NaN
# 3                         NaN                  NaN                  NaN
# 4                         NaN             1.000000                  NaN
# ...                       ...                  ...                  ...
# 896958                    NaN             0.000000                  NaN
# 896959                    NaN                  NaN                  NaN
# 896960                    NaN             0.000000                  NaN
# 896961                    NaN             0.130443             0.086946
# 896962                    NaN             1.000000                  NaN
#
#         Rolling90Pct_Cricket  Rolling90Pct_Beach  Rolling90Pct_Basketball  \
# 0                        NaN                 NaN                 1.000000
# 1                        NaN                 NaN                 0.000000
# 2                        NaN                 NaN                      NaN
# 3                        NaN                 NaN                      NaN
# 4                        NaN                 0.0                      NaN
# ...                      ...                 ...                      ...
# 896958                   NaN                 NaN                      NaN
# 896959                   NaN                 1.0                      NaN
# 896960                   NaN                 NaN                      NaN
# 896961                   NaN                 NaN                 0.579672
# 896962                   NaN                 NaN                      NaN
#
#         Rolling90Pct_Rugby  Rolling90Pct_Golf  Rolling90Pct_Softball  \
# 0                      0.0                NaN                    NaN
# 1                      NaN                NaN                    NaN
# 2                      NaN                NaN                    NaN
# 3                      0.0                NaN                    NaN
# 4                      NaN                NaN                    0.0
# ...                    ...                ...                    ...
# 896958                 NaN                NaN                    NaN
# 896959                 NaN                NaN                    NaN
# 896960                 1.0                NaN                    NaN
# 896961                 NaN                NaN                    NaN
# 896962                 NaN                NaN                    NaN
#
#         Rolling90Pct_Cycling  Rolling90Pct_Volleyball  Rolling90Pct_Running  \
# 0                        NaN                      NaN                   NaN
# 1                        NaN                      NaN                   NaN
# 2                        NaN                      NaN                   NaN
# 3                   1.000000                      NaN                   NaN
# 4                   0.000000                      NaN                   NaN
# ...                      ...                      ...                   ...
# 896958                   NaN                      NaN                   NaN
# 896959                   NaN                      NaN                   NaN
# 896960                   NaN                      NaN                   NaN
# 896961              0.202938                      NaN                   NaN
# 896962                   NaN                      NaN                   NaN
#
#         Rolling90Pct_Skiing
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 896958                  NaN
# 896959                  NaN
# 896960                  NaN
# 896961                  NaN
# 896962                  NaN
#
# [896963 rows x 58 columns]

# %%
final_df.dtypes
final_df #CONTROLLARE I MISSING VALUES QUA E I VALORI MASSIMI E MINIMI DA DATA WRANGLER
# Out:
#                    ClientID            ProductID TransactionDate  \
# 0       4388436561084682799  3260004767786243986      2023-01-01
# 1       5475934562856106533  4081002095016762501      2023-01-01
# 2       7571493122530801912  6392464777854173474      2023-01-01
# 3       9054036776577299596  4007202900314609762      2023-01-01
# 4       7828763863563966653  1064014581685647413      2023-01-01
# ...                     ...                  ...             ...
# 896958  8280531702429788495  1807418090523306919      2025-02-15
# 896959  8814766099908862144  3812923463855630464      2025-02-15
# 896960  7222914074110101995  8416641728304029823      2025-02-15
# 896961  3501418887043844736  1923991482221095632      2025-02-15
# 896962    20050540156575761  6088547929558282457      2025-02-15
#
#                     StoreID StoreCountry    Category FamilyLevel1  \
# 0       1913433680162801979          USA  Basketball         Ball
# 1       7704230050291051317          GBR    Baseball         Ball
# 2       6490882301505443815          USA    Football         Ball
# 3       8616445013777361432          USA     Cycling         Bike
# 4       7215875119995113089          AUS      Tennis       Racket
# ...                     ...          ...         ...          ...
# 896958  7242889412692100661          USA    Football       Shorts
# 896959  9099531021898466037          USA       Beach      Goggles
# 896960  7242889412692100661          USA       Rugby         Ball
# 896961  6056406535832467469          USA     Cycling         Bike
# 896962  6300325018935366047          USA      Tennis         Ball
#
#                        FamilyLevel2 Universe ClientSegment ClientGender   Age  \
# 0       Wilson Evolution Basketball    Women         LOYAL            M  50.0
# 1                      Wilson A1030      Men         LOYAL            M  25.0
# 2                      Puma Final 1    Women         LOYAL            F   NaN
# 3       Specialized S-Works Roubaix      Men         LOYAL            F  25.0
# 4             Wilson Pro Staff RF97      Men         LOYAL            F   NaN
# ...                             ...      ...           ...          ...   ...
# 896958                 Nike Dri-FIT    Women         LOYAL            M   NaN
# 896959        Speedo Vanquisher 2.0      Men         LOYAL            F   NaN
# 896960               Adidas Torpedo      Men           TOP            M  28.0
# 896961  Specialized S-Works Roubaix    Women         LOYAL            M   NaN
# 896962            Penn Championship    Women   INACTIVE_1Y            M   NaN
#
#        ClientCountry  ClientOptINEmail  ClientOptINPhone  Quantity_sold  \
# 0                USA                 1                 1              2
# 1                ARE                 0                 0              1
# 2                USA                 1                 1              1
# 3                USA                 0                 0              2
# 4                AUS                 0                 0              5
# ...              ...               ...               ...            ...
# 896958           USA                 1                 1              1
# 896959           USA                 1                 1              6
# 896960           USA                 1                 1              3
# 896961           USA                 1                 1              2
# 896962           USA                 1                 0              2
#
#         SalesNetAmountEuro  product_avg_price_order  avg_price   Weekday  \
# 0                    23.99                11.995000  16.753593    Sunday
# 1                    15.99                15.990000   9.004447    Sunday
# 2                     5.99                 5.990000   4.018489    Sunday
# 3                   103.99                51.995000  65.680625    Sunday
# 4                    67.96                13.592000  12.524243    Sunday
# ...                    ...                      ...        ...       ...
# 896958                5.99                 5.990000  13.183265  Saturday
# 896959               41.98                 6.996667   5.493780  Saturday
# 896960               37.98                12.660000  13.500647  Saturday
# 896961               41.99                20.995000  24.636184  Saturday
# 896962               23.99                11.995000  15.327209  Saturday
#
#               Brand  DaysSinceLastTransaction  CumulativeSpent  \
# 0            Wilson                         0            23.99
# 1            Wilson                         0            15.99
# 2              Puma                         0             5.99
# 3       Specialized                         0           103.99
# 4            Wilson                         0            67.96
# ...             ...                       ...              ...
# 896958         Nike                         4           251.89
# 896959       Speedo                         1           190.86
# 896960       Adidas                        15          1025.72
# 896961  Specialized                         4           378.84
# 896962         Penn                         0            23.99
#
#         CumulativeQuantity  PercentageMaleProductsSoFar MostBoughtBrandSoFar  \
# 0                        2                     0.000000               Wilson
# 1                        1                     1.000000               Wilson
# 2                        1                     0.000000                 Puma
# 3                        2                     1.000000          Specialized
# 4                        5                     1.000000               Wilson
# ...                    ...                          ...                  ...
# 896958                  15                     0.733333                 Nike
# 896959                  27                     0.333333               Speedo
# 896960                  41                     0.243902               Adidas
# 896961                  24                     0.375000               Wilson
# 896962                   2                     0.000000                 Penn
#
#         UniqueProductsSoFar  AverageAmountPerTransactionSoFar  \
# 0                         1                         23.990000
# 1                         1                         15.990000
# 2                         1                          5.990000
# 3                         1                        103.990000
# 4                         1                         67.960000
# ...                     ...                               ...
# 896958                    6                         27.987778
# 896959                    5                         27.265714
# 896960                   21                         48.843810
# 896961                    8                         34.440000
# 896962                    1                         23.990000
#
#         AverageFrequencySoFar  AveragePrice  DayOfWeek  Month  Season  \
# 0                      900.00     16.753593          6      1  Winter
# 1                      900.00      9.004447          6      1  Winter
# 2                      900.00      4.018489          6      1  Winter
# 3                      900.00     65.680625          6      1  Winter
# 4                      900.00     12.524243          6      1  Winter
# ...                       ...           ...        ...    ...     ...
# 896958                  70.00     13.183265          5      2  Winter
# 896959                   4.00      5.493780          5      2  Winter
# 896960                  34.95     13.500647          5      2  Winter
# 896961                  30.60     24.636184          5      2  Winter
# 896962                 900.00     15.327209          5      2  Winter
#
#         Frequency_30  Monetary_30  Recency_30  Frequency_60  Monetary_60  \
# 0                1.0        23.99           0           1.0        23.99
# 1                1.0        15.99           0           1.0        15.99
# 2                1.0         5.99           0           1.0         5.99
# 3                1.0       103.99           0           1.0       103.99
# 4                1.0        67.96           0           1.0        67.96
# ...              ...          ...         ...           ...          ...
# 896958           3.0        73.96           0           3.0        73.96
# 896959           7.0       190.86           0           7.0       190.86
# 896960           2.0        99.97           0           2.0        99.97
# 896961           7.0       206.91           0           7.0       206.91
# 896962           1.0        23.99           0           1.0        23.99
#
#         Recency_60  Frequency_90  Monetary_90  Recency_90  \
# 0                0           1.0        23.99           0
# 1                0           1.0        15.99           0
# 2                0           1.0         5.99           0
# 3                0           1.0       103.99           0
# 4                0           1.0        67.96           0
# ...            ...           ...          ...         ...
# 896958           0           3.0        73.96           0
# 896959           0           7.0       190.86           0
# 896960           0           2.0        99.97           0
# 896961           0           7.0       206.91           0
# 896962           0           1.0        23.99           0
#
#         Rolling90Pct_Football  Rolling90Pct_Handball  Rolling90Pct_Badminton  \
# 0                         NaN                    NaN                     NaN
# 1                         0.0                    0.0                     0.0
# 2                         1.0                    0.0                     NaN
# 3                         NaN                    NaN                     NaN
# 4                         0.0                    0.0                     0.0
# ...                       ...                    ...                     ...
# 896958                    1.0                    0.0                     NaN
# 896959                    NaN                    NaN                     NaN
# 896960                    0.0                    0.0                     NaN
# 896961                    NaN                    NaN                     NaN
# 896962                    NaN                    NaN                     NaN
#
#         Rolling90Pct_Baseball  Rolling90Pct_Tennis  Rolling90Pct_Hockey  \
# 0                         NaN                  NaN                  NaN
# 1                         1.0                  NaN             0.000000
# 2                         NaN             0.000000                  NaN
# 3                         NaN                  NaN                  NaN
# 4                         NaN             1.000000                  NaN
# ...                       ...                  ...                  ...
# 896958                    NaN             0.000000                  NaN
# 896959                    NaN                  NaN                  NaN
# 896960                    NaN             0.000000                  NaN
# 896961                    NaN             0.130443             0.086946
# 896962                    NaN             1.000000                  NaN
#
#         Rolling90Pct_Cricket  Rolling90Pct_Beach  Rolling90Pct_Basketball  \
# 0                        NaN                 NaN                 1.000000
# 1                        NaN                 NaN                 0.000000
# 2                        NaN                 NaN                      NaN
# 3                        NaN                 NaN                      NaN
# 4                        NaN                 0.0                      NaN
# ...                      ...                 ...                      ...
# 896958                   NaN                 NaN                      NaN
# 896959                   NaN                 1.0                      NaN
# 896960                   NaN                 NaN                      NaN
# 896961                   NaN                 NaN                 0.579672
# 896962                   NaN                 NaN                      NaN
#
#         Rolling90Pct_Rugby  Rolling90Pct_Golf  Rolling90Pct_Softball  \
# 0                      0.0                NaN                    NaN
# 1                      NaN                NaN                    NaN
# 2                      NaN                NaN                    NaN
# 3                      0.0                NaN                    NaN
# 4                      NaN                NaN                    0.0
# ...                    ...                ...                    ...
# 896958                 NaN                NaN                    NaN
# 896959                 NaN                NaN                    NaN
# 896960                 1.0                NaN                    NaN
# 896961                 NaN                NaN                    NaN
# 896962                 NaN                NaN                    NaN
#
#         Rolling90Pct_Cycling  Rolling90Pct_Volleyball  Rolling90Pct_Running  \
# 0                        NaN                      NaN                   NaN
# 1                        NaN                      NaN                   NaN
# 2                        NaN                      NaN                   NaN
# 3                   1.000000                      NaN                   NaN
# 4                   0.000000                      NaN                   NaN
# ...                      ...                      ...                   ...
# 896958                   NaN                      NaN                   NaN
# 896959                   NaN                      NaN                   NaN
# 896960                   NaN                      NaN                   NaN
# 896961              0.202938                      NaN                   NaN
# 896962                   NaN                      NaN                   NaN
#
#         Rolling90Pct_Skiing
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 896958                  NaN
# 896959                  NaN
# 896960                  NaN
# 896961                  NaN
# 896962                  NaN
#
# [896963 rows x 58 columns]
